# %% [markdown]
# # 🔬 AA-CLIP: Reproduce Paper — Kaggle Notebook (CVPR 2025)
#
# ## 🎯 Mục tiêu: Tái tạo kết quả Zero-Shot Anomaly Detection
#
# ### Cross-Dataset Protocol (theo Section 4.1 trong paper)
#
# AA-CLIP là **Zero-Shot AD**: model KHÔNG được nhìn thấy test dataset trong lúc train.
# Tác giả dùng chiến lược **train chéo dataset**:
#
# ```
# TRAIN trên VisA  ──→  TEST zero-shot trên MVTec, BTAD, MPDD, Brain, Liver, Colon...
# TRAIN trên MVTec ──→  TEST zero-shot trên VisA
# ```
#
# **Notebook này thực hiện: Train VisA → Test MVTec** (tái tạo Table 1 trong paper)
#
# ### Hyperparameters theo paper (Implementation Details + Appendix A.3)
#
# | Param | Giá trị | Nguồn |
# |---|---|---|
# | Backbone | ViT-L/14-336 (OpenCLIP) | Main paper |
# | Image size | 518×518 | Main paper |
# | K_T (text layers) | 3 | Main paper |
# | K_I (image layers) | 6 | Main paper |
# | λ, γ | 0.1 | Main paper |
# | Stage 1 text_batch_size | **16** | Appendix A.3 |
# | Stage 2 image_batch_size | **2** | Appendix A.3 |
# | Stage 1 LR | 1×10⁻⁵, 5 epochs | Main paper |
# | Stage 2 LR | 5×10⁻⁴, 20 epochs | Main paper |
# | Adam β₁, β₂ | 0.5, 0.999 | Appendix A.3 |
# | GPU (paper) | RTX 3090 24GB | Main paper |
# | GPU (ta dùng) | Tesla P100 16GB | Kaggle |
#
# > ⚠️ **Lưu ý P100 16GB:** text_batch_size=16 ổn (Stage 1 dùng no_grad cho image).
# > Nếu Stage 2 OOM, giảm image_batch_size từ 2 xuống 1.
#
# ---
# ## 🗂️ Dataset cần Add vào notebook này
#
# Vào **"Add data"** → tìm từng dataset → Add:
#
# | Dataset | Vai trò | Kaggle ID | Mount path |
# |---|---|---|---|
# | **VisA** | TRAIN | `tensura3607/amazon-visa-anomaly` | `/kaggle/input/amazon-visa-anomaly/` |
# | **MVTec AD** | TEST | `ipythonx/mvtec-ad` | `/kaggle/input/mvtec-ad/` |

# %% [markdown]
# ## Cell 1: Setup — Clone, Fix bugs, Cài thư viện

# %%
# %cd /kaggle/working

# %%
# !rm -r deeplearning_AACLIP

# %%
import os

# 1. Clone repo (bản đã refactor có config.yaml)
# !git clone https://github.com/duonguwu/deeplearning_AACLIP.git
# %cd deeplearning_AACLIP/AA-CLIP

# 2. Fix 'import ipdb' → crash ngay khi import trên Kaggle
files_to_fix = [
    'train.py', 
    'forward_utils.py', 
    'model/adapter_modules.py', 
    'model/transformer.py'
]
for fname in files_to_fix:
    with open(fname, 'r') as f: code = f.read()
    code = code.replace('import ipdb\n', '# import ipdb\n')
    with open(fname, 'w') as f: f.write(code)
print('✅ Fixed: ipdb imports')

# 3. Fix bug resume logic trong train.py
#    Bug: not(epoch == text_epoch-1) → sai khi resume từ checkpoint
#    Fix: epoch < text_epoch
with open('train.py', 'r') as f:
    code = f.read()
code = code.replace(
    'adapt_text = not (text_start_epoch == (args.text_epoch - 1))',
    'adapt_text = text_start_epoch < args.text_epoch  # bugfix'
)
with open('train.py', 'w') as f:
    f.write(code)
print('✅ Fixed: epoch resume logic')

# 4. Cài thư viện
# !pip install -q open_clip_torch pyyaml ftfy kornia==0.6.9 timm==0.6.12 scikit-learn pandas
print('✅ Dependencies installed')
# Out:
# Cloning into 'deeplearning_AACLIP'...
# remote: Enumerating objects: 108, done.
# remote: Counting objects: 100% (108/108), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 108 (delta 25), reused 97 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (108/108), 11.21 MiB | 32.69 MiB/s, done.
# Resolving deltas: 100% (25/25), done.
# /kaggle/working/deeplearning_AACLIP/AA-CLIP
# ✅ Fixed: ipdb imports
# ✅ Fixed: epoch resume logic
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 569.1/569.1 kB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 kB 35.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 57.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.1 MB/s eta 0:00:00
# ✅ Dependencies installed

# %%
# !pwd
# Out:
# /kaggle/working/deeplearning_AACLIP/AA-CLIP

# %% [markdown]
# ## Cell 2: Cấu hình Dataset Paths (config.yaml)
#
# **VisA = dataset dùng để TRAIN** (mount tại `/kaggle/input/amazon-visa-anomaly/VisA_20220922/`)
#
# **MVTec = dataset dùng để TEST** (mount tại `/kaggle/input/mvtec-ad/`)
#
# Paths đã điền sẵn cho 2 Kaggle dataset IDs trên — không cần sửa nếu dùng đúng 2 dataset đó.

# %%
import yaml, os


BASE_PATH = "/kaggle/input/datasets"

VISA_FOLDER  = "tensura3607/amazon-visa-anomaly"
MVTEC_FOLDER = "ipythonx/mvtec-ad"

config = {
    'paths': {
        'base_path': BASE_PATH,
        'datasets': {
            'Brain':          'MedAD/Brain_AD',
            'Liver':          'MedAD/Liver_AD',
            'Retina':         'MedAD/Retina_RESC_AD',
            'Colon_clinicDB': 'Colon/CVC-ClinicDB',
            'Colon_colonDB':  'Colon/CVC-ColonDB',
            'Colon_cvc300':   'Colon/CVC-300',
            'Colon_Kvasir':   'Colon/Kvasir',
            'BTAD':           'BTech_Dataset_transformed',
            'MPDD':           'MPDD',
            'MVTec':          MVTEC_FOLDER,
            'VisA':           VISA_FOLDER,
        }
    }
}

with open('config.yaml', 'w') as f:
    yaml.dump(config, f, default_flow_style=False, allow_unicode=True)

print('✅ config.yaml đã tạo xong')
print(f'   [TRAIN] VisA  : {BASE_PATH}/{VISA_FOLDER}')
print(f'   [TEST]  MVTec : {BASE_PATH}/{MVTEC_FOLDER}')
# /kaggle/input/datasets/tensura3607/amazon-visa-anomaly
# /kaggle/input/datasets/ipythonx/mvtec-ad
# Out:
# ✅ config.yaml đã tạo xong
#    [TRAIN] VisA  : /kaggle/input/datasets/tensura3607/amazon-visa-anomaly
#    [TEST]  MVTec : /kaggle/input/datasets/ipythonx/mvtec-ad

# %% [markdown]
# ## Cell 3: Verify GPU & Dataset Paths
#
# Chạy cell này trước. **VisA (TRAIN) và MVTec (TEST) phải hiện `✅`** mới tiếp tục.

# %%
# !find /kaggle/input -maxdepth 3 -type d | sort | head -100
# Out:
# /kaggle/input
# /kaggle/input/datasets
# /kaggle/input/datasets/ipythonx
# /kaggle/input/datasets/ipythonx/mvtec-ad
# /kaggle/input/datasets/tensura3607
# /kaggle/input/datasets/tensura3607/amazon-visa-anomaly

# %%
import os, yaml

print('GPU INFO:')
# !nvidia-smi --query-gpu=name,memory.total,memory.free --format=csv,noheader

print('\nDATASET PATHS CHECK:')
with open('config.yaml') as f:
    cfg = yaml.safe_load(f)

base = cfg['paths']['base_path']
critical = ['MVTec', 'VisA']  # Hai dataset bắt buộc phải có
all_critical_ok = True

for name, sub in cfg['paths']['datasets'].items():
    full = os.path.join(base, sub)
    ok   = os.path.exists(full)
    role = '[TRAIN]' if name == 'VisA' else '[TEST] ' if name == 'MVTec' else '       '
    tag  = '✅' if ok else '❌'
    print(f'  {role} {name:<20s}: {tag}  {full}')
    if name in critical and not ok:
        all_critical_ok = False

print()
if all_critical_ok:
    print('✅ VisA (TRAIN) + MVTec (TEST) đều OK — Ready!')
else:
    print('❌ Thiếu dataset quan trọng! Kiểm tra lại "Add data".')

# print('\nCấu trúc bên trong VisA (train):')
# !find /kaggle/input/datasets/tensura3607/amazon-visa-anomaly -maxdepth 2 -type d | sort | head -20

# print('\nCấu trúc bên trong MVTec (test):')
# !find /kaggle/input/datasets/ipythonx/mvtec-ad -maxdepth 2 -type d | sort | head -20
# Out:
# GPU INFO:
# Tesla T4, 15360 MiB, 14913 MiB
# Tesla T4, 15360 MiB, 14913 MiB
#
# DATASET PATHS CHECK:
#           BTAD                : ❌  /kaggle/input/datasets/BTech_Dataset_transformed
#           Brain               : ❌  /kaggle/input/datasets/MedAD/Brain_AD
#           Colon_Kvasir        : ❌  /kaggle/input/datasets/Colon/Kvasir
#           Colon_clinicDB      : ❌  /kaggle/input/datasets/Colon/CVC-ClinicDB
#           Colon_colonDB       : ❌  /kaggle/input/datasets/Colon/CVC-ColonDB
#           Colon_cvc300        : ❌  /kaggle/input/datasets/Colon/CVC-300
#           Liver               : ❌  /kaggle/input/datasets/MedAD/Liver_AD
#           MPDD                : ❌  /kaggle/input/datasets/MPDD
#   [TEST]  MVTec               : ✅  /kaggle/input/datasets/ipythonx/mvtec-ad
#           Retina              : ❌  /kaggle/input/datasets/MedAD/Retina_RESC_AD
#   [TRAIN] VisA                : ✅  /kaggle/input/datasets/tensura3607/amazon-visa-anomaly
#
# ✅ VisA (TRAIN) + MVTec (TEST) đều OK — Ready!

# %% [markdown]
# ## 2. Download OpenCLIP ViT-L-14-336px weights

# %%
# !pip show timm
# Out:
# Name: timm
# Version: 0.6.12
# Summary: (Unofficial) PyTorch Image Models
# Home-page: https://github.com/rwightman/pytorch-image-models
# Author: Ross Wightman
# Author-email: hello@rwightman.com
# License: UNKNOWN
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: huggingface-hub, pyyaml, torch, torchvision
# Required-by: open_clip_torch

# %%
import urllib.request
import os

model_dir = '/kaggle/working/deeplearning_AACLIP/AA-CLIP/model'
model_path = os.path.join(model_dir, 'ViT-L-14-336px.pt')

if not os.path.exists(model_path):
    url = 'https://openaipublic.azureedge.net/clip/models/3035c92b350959924f9f00213499208652fc7ea050643e8b385c2dac08641f02/ViT-L-14-336px.pt'
    print('Downloading ViT-L-14-336px.pt from OpenAI (~1.7GB)...')
    urllib.request.urlretrieve(url, model_path)
    print('Done!')
else:
    print('Model already exists:', model_path)
# Out:
# Downloading ViT-L-14-336px.pt from OpenAI (~1.7GB)...
# Done!

# %%
# Kiểm tra file
# !find /kaggle/working/deeplearning_AACLIP/AA-CLIP/model -name '*.pt' -o -name '*.bin' 2>/dev/null | head -5
# Out:
# /kaggle/working/deeplearning_AACLIP/AA-CLIP/model/ViT-L-14-336px.pt

# %% [markdown]
# ---
# ## 4. Training: Cross-Dataset Zero-Shot Protocol
#
# ```
#         ┌─────────────────────────────────────────────────────┐
#         │  TRAIN trên VisA (2162 samples: 962 normal + 1200 anomaly)
#         │     ↓ Stage 1: Text Adapter (5 epochs)
#         │     ↓ Stage 2: Image Adapter (20 epochs)
#         │  TEST zero-shot trên MVTec (model chưa thấy MVTec)
#         └─────────────────────────────────────────────────────┘
# ```
#
# **Tại sao P100 16GB chịu được text_batch_size=16?**
# Stage 1 compute image features bằng `torch.no_grad()` → không lưu gradient cho image
# → Memory chủ yếu từ text adapter (nhỏ) → P100 16GB hoàn toàn đủ.

# %% [markdown]
# ### Stage 1: Huấn luyện Text Adapter (train trên VisA)
#
# Text Adapter học cách biểu diễn `Normal` vs `Anomaly` từ dữ liệu VisA.
# Sau đó trọng số này sẽ được dùng **zero-shot** để test trên MVTec.
#
# | Hyperparameter | Giá trị (paper) |
# |---|---|
# | Epochs | 5 |
# | Learning Rate | 1×10⁻⁵ |
# | **text_batch_size** | **16** (đúng theo Appendix A.3) |
# | Optimizer | Adam (β₁=0.5, β₂=0.999) |
#
# > ⏱️ Ước tính: ~30–60 phút trên P100 16GB (VisA full-shot 2162 samples)

# %%
import torch
print("PyTorch version:", torch.__version__)
print("CUDA version:", torch.version.cuda)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
    print("Compute capability:", torch.cuda.get_device_capability(0))
    # Test cơ bản
    try:
        x = torch.randn(2, 2).cuda()
        print("Basic CUDA test: ✅ PASSED")
    except Exception as e:
        print(f"Basic CUDA test: ❌ FAILED - {e}")
# Out:
# PyTorch version: 2.10.0+cu128
# CUDA version: 12.8
# CUDA available: True
# GPU name: Tesla T4
# Compute capability: (7, 5)
# Basic CUDA test: ✅ PASSED

# %%
import os

TRAIN_DATASET    = 'VisA'   # Train trên VisA (cross-dataset protocol)
SAVE_PATH        = f'/kaggle/working/aaclip_ckpt/visa_trained'
TEXT_BATCH_SIZE  = 4       # Đúng theo paper Appendix A.3
IMAGE_BATCH_SIZE = 2        # Đúng theo paper Appendix A.3

os.makedirs(SAVE_PATH, exist_ok=True)
print(f'Train dataset : {TRAIN_DATASET}')
print(f'Save path     : {SAVE_PATH}')
print(f'text_batch    : {TEXT_BATCH_SIZE}  (paper default)')
print(f'image_batch   : {IMAGE_BATCH_SIZE}  (paper default)')
print('Bắt đầu Stage 1: Train Text Adapter (5 epochs)...')
print('=' * 60)

# image_epoch=0 → chỉ train Text Adapter, Image Adapter loop không chạy
# !python train.py \
    --dataset {TRAIN_DATASET} \
    --training_mode full_shot \
    --save_path {SAVE_PATH} \
    --text_epoch 5 \
    --accum_steps 4 \
    --image_epoch 0  \
    --text_lr 0.00001 \
    --text_batch_size {TEXT_BATCH_SIZE} \
    --image_batch_size {IMAGE_BATCH_SIZE} \
    --text_adapt_until 3 \
    --image_adapt_until 6 \
    --text_norm_weight 0.1 \
    --text_adapt_weight 0.1 \
    --image_adapt_weight 0.1 \
    --img_size 518 \
    --seed 111

print('\n✅ Stage 1 hoàn thành!')
# !ls -lh {SAVE_PATH}/text_adapter.pth
# Out:
# Train dataset : VisA
# Save path     : /kaggle/working/aaclip_ckpt/visa_trained
# text_batch    : 4  (paper default)
# image_batch   : 2  (paper default)
# Bắt đầu Stage 1: Train Text Adapter (5 epochs)...
# ============================================================
# 100%|█████████████████████████████████████████| 541/541 [14:15<00:00,  1.58s/it]
# 100%|█████████████████████████████████████████| 541/541 [14:16<00:00,  1.58s/it]
# 100%|█████████████████████████████████████████| 541/541 [14:17<00:00,  1.59s/it]
# 100%|█████████████████████████████████████████| 541/541 [14:18<00:00,  1.59s/it]
# 100%|█████████████████████████████████████████| 541/541 [14:36<00:00,  1.62s/it]
#
# ✅ Stage 1 hoàn thành!
# -rw-r--r-- 1 root root 28M May 20 19:39 /kaggle/working/aaclip_ckpt/visa_trained/text_adapter.pth

# %%
# !zip -r /kaggle/working/stage1_checkpoint.zip /kaggle/working/aaclip_ckpt/
print("📦 File zip đã sẵn sàng tải!")
# !ls -lh /kaggle/working/stage1_checkpoint.zip
# Out:
#   adding: kaggle/working/aaclip_ckpt/ (stored 0%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/ (stored 0%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/text_adapter.pth (deflated 8%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/train.log (deflated 60%)
# 📦 File zip đã sẵn sàng tải!
# -rw-r--r-- 1 root root 25M May 20 19:39 /kaggle/working/stage1_checkpoint.zip

# %% [markdown]
# ### Stage 2: Huấn luyện Image Adapter (tiếp tục trên VisA)
#
# Image Adapter căn chỉnh patch features với text anchors đã học ở Stage 1.
# Backbone **đóng băng hoàn toàn**.
#
# | Hyperparameter | Giá trị (paper) |
# |---|---|
# | Epochs | 20 |
# | Learning Rate | 5×10⁻⁴ |
# | **image_batch_size** | **2** (đúng theo Appendix A.3) |
# | LR Scheduler | MultiStepLR ×0.5 tại step 16k, 32k |
#
# > ⚠️ Nếu P100 bị OOM ở Stage 2: giảm image_batch_size xuống **1**
#
# > ⏱️ Ước tính: ~4–6 giờ trên P100 16GB (VisA full-shot, 20 epochs)

# %%
import os

TRAIN_DATASET    = 'VisA'
SAVE_PATH        = '/kaggle/working/aaclip_ckpt/visa_trained'
TEXT_BATCH_SIZE  = 16
IMAGE_BATCH_SIZE = 1   # ← Giảm xuống 1 nếu P100 bị OOM

text_ckpt = f'{SAVE_PATH}/text_adapter.pth'
if not os.path.exists(text_ckpt):
    print('❌ Không tìm thấy text_adapter.pth! Chạy Stage 1 trước.')
else:
    print(f'✅ text_adapter.pth found')
    print('Bắt đầu Stage 2: Train Image Adapter (20 epochs)...')
    print('=' * 60)

    # text_epoch=5 → code load text_adapter.pth, kiểm tra (5 < 5 = False)
    # → bỏ qua text training → chỉ train Image Adapter
    # !python train.py \
        --dataset {TRAIN_DATASET} \
        --training_mode full_shot \
        --save_path {SAVE_PATH} \
        --text_epoch 5 \
        --image_epoch 20 \
        --accum_steps 1 \
        --text_lr 0.00001 \
        --image_lr 0.0005 \
        --text_batch_size {TEXT_BATCH_SIZE} \
        --image_batch_size {IMAGE_BATCH_SIZE} \
        --text_adapt_until 3 \
        --image_adapt_until 6 \
        --text_norm_weight 0.1 \
        --text_adapt_weight 0.1 \
        --image_adapt_weight 0.1 \
        --img_size 518 \
        --seed 111

    print('\n✅ Stage 2 hoàn thành!')
    print('Checkpoints:')
    # !ls -lh {SAVE_PATH}/image_adapter*.pth | tail -5
# Out:
# ✅ text_adapter.pth found
# Bắt đầu Stage 2: Train Image Adapter (20 epochs)...
# ============================================================
# 100%|███████████████████████████████████████| 2162/2162 [19:24<00:00,  1.86it/s]
# 100%|███████████████████████████████████████| 2162/2162 [19:22<00:00,  1.86it/s]
# 100%|███████████████████████████████████████| 2162/2162 [19:25<00:00,  1.86it/s]
# 100%|███████████████████████████████████████| 2162/2162 [19:30<00:00,  1.85it/s]
# 100%|███████████████████████████████████████| 2162/2162 [19:25<00:00,  1.85it/s]
# 100%|███████████████████████████████████████| 2162/2162 [19:24<00:00,  1.86it/s]
# 100%|███████████████████████████████████████| 2162/2162 [19:23<00:00,  1.86it/s]
# 100%|███████████████████████████████████████| 2162/2162 [19:24<00:00,  1.86it/s]
# 100%|███████████████████████████████████████| 2162/2162 [19:25<00:00,  1.85it/s]
# 100%|███████████████████████████████████████| 2162/2162 [19:27<00:00,  1.85it/s]
# 100%|███████████████████████████████████████| 2162/2162 [19:27<00:00,  1.85it/s]
# 100%|███████████████████████████████████████| 2162/2162 [19:28<00:00,  1.85it/s]
# 100%|███████████████████████████████████████| 2162/2162 [19:26<00:00,  1.85it/s]
# 100%|███████████████████████████████████████| 2162/2162 [19:29<00:00,  1.85it/s]
# 100%|███████████████████████████████████████| 2162/2162 [19:36<00:00,  1.84it/s]
# 100%|███████████████████████████████████████| 2162/2162 [19:33<00:00,  1.84it/s]
# 100%|███████████████████████████████████████| 2162/2162 [19:30<00:00,  1.85it/s]
# 100%|███████████████████████████████████████| 2162/2162 [19:30<00:00,  1.85it/s]
# 100%|███████████████████████████████████████| 2162/2162 [19:30<00:00,  1.85it/s]
# 100%|███████████████████████████████████████| 2162/2162 [19:31<00:00,  1.85it/s]
#
# ✅ Stage 2 hoàn thành!
# Checkpoints:
# -rw-r--r-- 1 root root 118M May 20 21:36 /kaggle/working/aaclip_ckpt/visa_trained/image_adapter_6.pth
# -rw-r--r-- 1 root root 118M May 20 21:55 /kaggle/working/aaclip_ckpt/visa_trained/image_adapter_7.pth
# -rw-r--r-- 1 root root 118M May 20 22:15 /kaggle/working/aaclip_ckpt/visa_trained/image_adapter_8.pth
# -rw-r--r-- 1 root root 118M May 20 22:34 /kaggle/working/aaclip_ckpt/visa_trained/image_adapter_9.pth
# -rw-r--r-- 1 root root 118M May 21 02:09 /kaggle/working/aaclip_ckpt/visa_trained/image_adapter.pth

# %% [markdown]
# ---
# ## 5. Evaluation: Test Zero-Shot trên MVTec
#
# Model đã train trên VisA — giờ test **zero-shot** trên MVTec.
# Model chưa bao giờ thấy ảnh MVTec trong lúc train.
#
# `test.py` sẽ load từng `image_adapter_{epoch}.pth` (epoch 1→20),
# chạy inference trên 15 class của MVTec, tính Image/Pixel AUROC+AP.

# %%
TRAIN_DATASET = 'VisA'   # Checkpoint được train từ đây
TEST_DATASET  = 'MVTec'  # Test zero-shot trên MVTec
SAVE_PATH     = '/kaggle/working/aaclip_ckpt/visa_trained'

print(f'Train src : {TRAIN_DATASET}')
print(f'Test on   : {TEST_DATASET}  (zero-shot)')
print('=' * 60)

# !python test.py \
    --dataset {TEST_DATASET} \
    --save_path {SAVE_PATH} \
    --img_size 518 \
    --text_adapt_until 3 \
    --image_adapt_until 6 \
    --text_adapt_weight 0.1 \
    --image_adapt_weight 0.1 \
    --batch_size 8 \
    --seed 111

print('\n✅ Evaluation xong!')
print(f'Log: {SAVE_PATH}/test.log')
# Out:
# Train src : VisA
# Test on   : MVTec  (zero-shot)
# ============================================================
# 100%|███████████████████████████████████████████| 11/11 [00:35<00:00,  3.21s/it]
# 100%|███████████████████████████████████████████| 19/19 [01:00<00:00,  3.19s/it]
# 100%|███████████████████████████████████████████| 17/17 [00:54<00:00,  3.20s/it]
# 100%|███████████████████████████████████████████| 15/15 [00:48<00:00,  3.22s/it]
# 100%|███████████████████████████████████████████| 10/10 [00:32<00:00,  3.21s/it]
# 100%|███████████████████████████████████████████| 14/14 [00:45<00:00,  3.25s/it]
# 100%|███████████████████████████████████████████| 16/16 [00:51<00:00,  3.20s/it]
# 100%|███████████████████████████████████████████| 15/15 [00:47<00:00,  3.15s/it]
# 100%|███████████████████████████████████████████| 21/21 [01:07<00:00,  3.22s/it]
# 100%|███████████████████████████████████████████| 20/20 [01:04<00:00,  3.25s/it]
# 100%|███████████████████████████████████████████| 15/15 [00:48<00:00,  3.22s/it]
# 100%|███████████████████████████████████████████| 13/13 [00:41<00:00,  3.20s/it]
# 100%|█████████████████████████████████████████████| 6/6 [00:17<00:00,  2.95s/it]
# 100%|███████████████████████████████████████████| 10/10 [00:33<00:00,  3.37s/it]
# 100%|███████████████████████████████████████████| 19/19 [01:01<00:00,  3.21s/it]
# Traceback (most recent call last):
#   File "/kaggle/working/deeplearning_AACLIP/AA-CLIP/test.py", line 253, in <module>
#     main()
#   File "/kaggle/working/deeplearning_AACLIP/AA-CLIP/test.py", line 247, in main
#     df.loc[len(df)] = df.mean()
#                       ^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/core/frame.py", line 11720, in mean
#     result = super().mean(axis, skipna, numeric_only, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/core/generic.py", line 12485, in mean
#     return self._stat_function(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/core/generic.py", line 12442, in _stat_function
#     return self._reduce(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/core/frame.py", line 11589, in _reduce
#     res = df._mgr.reduce(blk_func)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py", line 1519, in reduce
#     nbs = blk.reduce(func)
#           ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/core/internals/blocks.py", line 406, in reduce
#     result = func(self.values)
#              ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/core/frame.py", line 11508, in blk_func
#     return op(values, axis=axis, skipna=skipna, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py", line 147, in f
#     result = alt(values, axis=axis, skipna=skipna, **kwds)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py", line 404, in new_func
#     result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py", line 720, in nanmean
#     the_sum = _ensure_numeric(the_sum)
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py", line 1686, in _ensure_numeric
#     raise TypeError(f"Could not convert {x} to numeric")
# TypeError: Could not convert ['bottlecablecapsulecarpetgridhazelnutleathermetal_nutpillscrewtiletransistortoothbrushwoodzipper'] to numeric
#
# ✅ Evaluation xong!
# Log: /kaggle/working/aaclip_ckpt/visa_trained/test.log

# %% [markdown]
# ## 6. Kết quả & So sánh với Paper (Table 1)
#
# Lấy kết quả epoch cuối (epoch 20) và so sánh với paper.

# %%
import pandas as pd

SAVE_PATH = '/kaggle/working/aaclip_ckpt/visa_trained'
LOG_PATH  = f'{SAVE_PATH}/test.log'

with open(LOG_PATH) as f:
    log = f.read()

# Lấy block kết quả của epoch cuối
blocks = log.split('load model from epoch')
print(f'Tổng số epochs đã eval: {len(blocks)-1}')
print('\n=== KẾT QUẢ EPOCH 20 (cuối) ===')
lines = [l.strip() for l in blocks[-1].split('\n') if l.strip()]
for l in lines:
    print(l)

print('\n=== SO SÁNH VỚI PAPER ===')
print('Protocol: Train VisA → Test MVTec zero-shot (Table 1, Full-shot)')
print()
# Số liệu từ Table 1 paper (full-shot, VisA→MVTec zero-shot)
# Xác nhận lại từ paper Table 1 cột MVTec, hàng AA-CLIP full-shot
comparison = pd.DataFrame({
    'Metric': ['Image AUROC', 'Image AP', 'Pixel AUROC', 'Pixel AP'],
    'Paper (CVPR 2025)': ['~91.1%', '~95.6%', '~56.2%', '~30.7%'],
    'Ours': ['→ xem log', '→ xem log', '→ xem log', '→ xem log'],
})
print(comparison.to_string(index=False))
print()
print('* Số liệu paper: Table 1, zero-shot, full-shot, MVTec AD.')
print('* Xác nhận lại giá trị chính xác từ file paper (Table 1).')
print('* Sai lệch <1% AUROC giữa P100 và RTX3090 là bình thường.')
# Out:
# Tổng số epochs đã eval: 1
#
# === KẾT QUẢ EPOCH 20 (cuối) ===
# 1
# INFO:__main__:-----------------------------------------------
# INFO:__main__:Class name: bottle
# INFO:__main__:Sample number: 83
# INFO:__main__:=====================================
# INFO:__main__:Class name: cable
# INFO:__main__:Sample number: 150
# INFO:__main__:=====================================
# INFO:__main__:Class name: capsule
# INFO:__main__:Sample number: 132
# INFO:__main__:=====================================
# INFO:__main__:Class name: carpet
# INFO:__main__:Sample number: 117
# INFO:__main__:=====================================
# INFO:__main__:Class name: grid
# INFO:__main__:Sample number: 78
# INFO:__main__:=====================================
# INFO:__main__:Class name: hazelnut
# INFO:__main__:Sample number: 110
# INFO:__main__:=====================================
# INFO:__main__:Class name: leather
# INFO:__main__:Sample number: 124
# INFO:__main__:=====================================
# INFO:__main__:Class name: metal_nut
# INFO:__main__:Sample number: 115
# INFO:__main__:=====================================
# INFO:__main__:Class name: pill
# INFO:__main__:Sample number: 167
# INFO:__main__:=====================================
# INFO:__main__:Class name: screw
# INFO:__main__:Sample number: 160
# INFO:__main__:=====================================
# INFO:__main__:Class name: tile
# INFO:__main__:Sample number: 117
# INFO:__main__:=====================================
# INFO:__main__:Class name: transistor
# INFO:__main__:Sample number: 100
# INFO:__main__:=====================================
# INFO:__main__:Class name: toothbrush
# INFO:__main__:Sample number: 42
# INFO:__main__:=====================================
# INFO:__main__:Class name: wood
# INFO:__main__:Sample number: 79
# INFO:__main__:=====================================
# INFO:__main__:Class name: zipper
# INFO:__main__:Sample number: 151
# INFO:__main__:=====================================
#
# === SO SÁNH VỚI PAPER ===
# Protocol: Train VisA → Test MVTec zero-shot (Table 1, Full-shot)
#
#      Metric Paper (CVPR 2025)      Ours
# Image AUROC            ~91.1% → xem log
#    Image AP            ~95.6% → xem log
# Pixel AUROC            ~56.2% → xem log
#    Pixel AP            ~30.7% → xem log
#
# * Số liệu paper: Table 1, zero-shot, full-shot, MVTec AD.
# * Xác nhận lại giá trị chính xác từ file paper (Table 1).
# * Sai lệch <1% AUROC giữa P100 và RTX3090 là bình thường.

# %% [markdown]
# ## 7. Lưu Checkpoint (Download về máy)
#
# Kaggle xóa `/kaggle/working` sau session. Zip lại để download.

# %%
SAVE_PATH = '/kaggle/working/aaclip_ckpt/visa_trained'
ZIP_OUT   = '/kaggle/working/aaclip_visa_trained_checkpoints.zip'

# !zip -r {ZIP_OUT} {SAVE_PATH}/
print(f'✅ Đã zip: {ZIP_OUT}')
# !ls -lh {ZIP_OUT}
# Out:
#   adding: kaggle/working/aaclip_ckpt/visa_trained/ (stored 0%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/text_adapter.pth (deflated 8%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/image_adapter_12.pth (deflated 9%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/image_adapter_9.pth (deflated 7%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/test.log (deflated 80%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/image_adapter_6.pth (deflated 7%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/image_adapter_15.pth (deflated 7%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/image_adapter_17.pth (deflated 8%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/image_adapter_14.pth (deflated 9%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/image_adapter_3.pth (deflated 7%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/image_adapter_1.pth (deflated 7%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/image_adapter_16.pth (deflated 7%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/image_adapter_10.pth (deflated 7%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/image_adapter_7.pth (deflated 7%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/image_adapter_20.pth (deflated 9%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/image_adapter_4.pth (deflated 7%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/image_adapter_13.pth (deflated 9%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/image_adapter_8.pth (deflated 7%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/train.log (deflated 77%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/image_adapter_2.pth (deflated 7%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/image_adapter_18.pth (deflated 8%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/image_adapter.pth (deflated 9%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/image_adapter_5.pth (deflated 7%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/image_adapter_19.pth (deflated 7%)
#   adding: kaggle/working/aaclip_ckpt/visa_trained/image_adapter_11.pth (deflated 9%)
# ✅ Đã zip: /kaggle/working/aaclip_visa_trained_checkpoints.zip
# -rw-r--r-- 1 root root 2.3G May 21 02:27 /kaggle/working/aaclip_visa_trained_checkpoints.zip
